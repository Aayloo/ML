# %% [markdown]
# # 06 · Robustness report
#
# Run the same pipeline for alternative signals and inspect cost-aware performance, drawdown, IC, and quantile spread together.

# %%
from pathlib import Path
from run_demo import run_demo

for signal_name in ['momentum', 'reversal', 'volatility', 'liquidity']:
    run_demo(Path('reports') / signal_name, signal_name=signal_name)
