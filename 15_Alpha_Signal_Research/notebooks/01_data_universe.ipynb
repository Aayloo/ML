# %% [markdown]
# # 01 · Data and universe
#
# Define the long-table contract and inspect the offline demo universe. Replace this loader only after documenting a licensed point-in-time data source.

# %%
from src.data import make_demo_market_data

market_data = make_demo_market_data(n_days=520, n_assets=24, seed=7)
market_data.head()
