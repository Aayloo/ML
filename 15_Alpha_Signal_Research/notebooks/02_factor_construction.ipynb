# %% [markdown]
# # 02 · Factor construction
#
# Build lagged Momentum, Reversal, Volatility, and Liquidity features. The forward return is a label, never an input feature.

# %%
from src.data import make_demo_market_data
from src.features import build_features

data = make_demo_market_data()
features = build_features(data, {'horizon': 5})
features.tail()
